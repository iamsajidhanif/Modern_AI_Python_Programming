# %%
def greet ():
  print("Hello World")
greet ()
# Out:
# Hello World

# %%
def sum( num1,num2 ):
  print( num1 + num2 )
sum(5, 10 )
# Out:
# 15

# %%
def calculator(num1, num2, operator):
  if operator == '+':
    print(num1 + num2)
  elif operator == '-':
    print(num1 - num2)
  elif operator == '*':
    print(num1 * num2)
  elif operator == '/':
    print(num1 / num2)
  else:
    print ("invalid operator")

calculator(5,7, '+')
# Out:
# 12

# %%
def calculator(num1, num2, operator):
  if operator == '+':
    print(num1 + num2)
  elif operator == '-':
    print(num1 - num2)
  elif operator == '*':
    print(num1 * num2)
  elif operator == '/':
    print(num1 / num2)
  else:
    print ("invalid operator")

#calculator(5,7, '+')
num1 = int(input("Enter First Number"))
operator = input("Enter your Operator")
num2 = int(input("Enter Second Number"))
calculator(num1, num2, operator)
# Out:
# Enter First Number9
# Enter your Operator+
# Enter Second Number44
# 53

# %%
def calculator(num1, num2, operator):
  if operator == '+':
    print(num1 + num2)
  elif operator == '-':
    print(num1 - num2)
  elif operator == '*':
    print(num1 * num2)
  elif operator == '/':
    print(num1 / num2)
  else:
    print ("invalid operator")

#calculator(5,7, '+')
num1 = int(input("Enter First Number"))
operator = input("Enter your Operator")
num2 = int(input("Enter Second Number"))
calculator(num1, num2, operator)
# Out:
# Enter First Number7
# Enter your Operator.
# Enter Second Number9
# invalid operator

# %%
def greet(age, name = "user"):
  print(f"hello {name} your age is {age}")
greet(37, "umair")
# Out:
# hello umair your age is 37

# %%
def greet(age, name = "user"):
  print(f"hello {name} your age is {age}")
greet(37)
# Out:
# hello user your age is 37
